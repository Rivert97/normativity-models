# %% [markdown]
# # This notebook evaluates the performance of RAG based on the given outputs

# %%
# Library imports
import os

import pandas as pd
import numpy as np
from rouge_score import rouge_scorer, scoring

# %%
# Global variables
MODELS = "Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think"
RESPONSES_PATH = '../evaluation/responses'

# %%
def calculate_rouge(predicted, reference):
    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL", "rougeLsum"], use_stemmer=True)
    aggregator = scoring.BootstrapAggregator()

    for pred, ref in zip(predicted, reference):
        score = scorer.score(ref, pred)
        aggregator.add_scores(score)
    result = aggregator.aggregate()

    return {metric: result[metric].mid.fmeasure for metric in result}

# %%
def calculate_rouge_by_file(predicted, reference, models):
    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL", "rougeLsum"], use_stemmer=True)
    aggregator = scoring.BootstrapAggregator()

    files = predicted['file'].unique()
    metrics = {
        'rouge1': np.zeros((len(files),), dtype=np.float32),
        'rouge2': np.zeros((len(files),), dtype=np.float32),
        'rougeL': np.zeros((len(files),), dtype=np.float32),
        'rougeLsum': np.zeros((len(files),), dtype=np.float32),
    }
    for f_idx, f in enumerate(files):
        file_predicted = predicted[predicted['file'] == f]
        file_reference = reference[reference['file'] == f]

        for pred, ref in zip(file_predicted['text'], file_reference['text']):
            single_score = scorer.score(ref, pred)
            aggregator.add_scores(single_score)
        result = aggregator.aggregate()
        score = {metric: result[metric].mid.fmeasure for metric in result}

        metrics['rouge1'][f_idx] = score['rouge1']
        metrics['rouge2'][f_idx] = score['rouge2']
        metrics['rougeL'][f_idx] = score['rougeL']
        metrics['rougeLsum'][f_idx] = score['rougeLsum']

    return pd.DataFrame({
            f'{models} rouge1': metrics['rouge1'],
            f'{models} rouge2': metrics['rouge2'],
            f'{models} rougeL': metrics['rougeL'],
            f'{models} rougeLsum': metrics['rougeLsum']
        },
        index=files)

# %%
# Loading the data
context = pd.read_csv(os.path.join(RESPONSES_PATH, MODELS, 'context.csv'), sep=',', index_col=0)
predicted = pd.read_csv(os.path.join(RESPONSES_PATH, MODELS, 'predicted.csv'), sep=',', index_col=0)
reference = pd.read_csv(os.path.join(RESPONSES_PATH, MODELS, 'reference.csv'), sep=',', index_col=0)

# %%
new_text = []
for text in predicted['text']:
    index = text.find('</think>\n\n')
    if index >= 0:
        new_text.append(text[index+10:])
    else:
        new_text.append(text)
#predicted['text'] = list(map(lambda item: item[1]['text'][item[1]['text'].find('</think>\n\n')+10:], predicted.iterrows()))
predicted['text'] = new_text

# %%
predicted['text']
# Out:
# 0       La Ley Orgánica de la Universidad de Guanajuat...
# 1       El fundamento legal que sustenta la **Ley Orgá...
# 2       Sí, la Universidad de Guanajuato es autónoma. ...
# 3       Los fines principales de la Universidad de Gua...
# 4       Los principios que rigen a la Universidad de G...
#                               ...
# 1824    El artículo séptimo del **Reglamento de Respon...
# 1825    La información proporcionada en los documentos...
# 1826    El Acuerdo de reforma al **Reglamento de Respo...
# 1827    Según el **Artículo Tercero (Ultractividad)** ...
# 1828    Las instancias universitarias competentes debe...
# Name: text, Length: 1828, dtype: object

# %%
rouge_score = calculate_rouge(
    [pred['text'] for _, pred in predicted.iterrows()],
    [ref['text'] for _, ref in reference.iterrows()]
)

rouge = pd.DataFrame(rouge_score, index=[MODELS])
rouge
# Out:
#                                                  rouge1    rouge2    rougeL  \
# Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think  0.234747  0.178373  0.215965
#
#                                                rougeLsum
# Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think   0.222188

# %%
rouge_by_file= calculate_rouge_by_file(predicted, reference, MODELS)
rouge_by_file
# Out:
#                                                     Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think rouge1  \
# ley-organica-de-la-universidad-de-guanajuato                                                 0.184700
# reglamento-del-personal-academico-de-la-univers...                                           0.284517
# reglamento-de-distinciones-universitarias-de-la...                                           0.310765
# reglamento-de-la-junta-directiva-de-la-universi...                                           0.306633
# reglamento-para-la-incorporacion-al-regimen-aca...                                           0.281312
# reglamento-interno-del-patronato-de-la-universi...                                           0.272187
# reglamento-de-quienes-integran-la-orquesta-sinf...                                           0.271232
# reglamento-academico-de-la-universidad-de-guana...                                           0.264448
# codigo-de-etica-de-las-personas-servidoras-publ...                                           0.260411
# reglamento-de-la-defensoria-de_los-derechos-hum...                                           0.265653
# reglamento-de-responsabilidades-y-sanciones-en-...                                           0.254326
# estatuto-organico-de-la-universidad-de-guanajuato                                            0.247488
# reglamento-de-transparencia-y-acceso-a-la-infor...                                           0.241377
# reglamento-de-bienes-del-patrimonio-cultural-de...                                           0.244777
# codigo-de-etica-universidad-de-guanajuato                                                    0.241965
# reglamento-del-programa-de-estimulos-al-dsempen...                                           0.241921
# codigo_conducta_e_integridad_personas_servidora...                                           0.239596
# reglamento-de-becas-apoyos-y-estimulos-estudian...                                           0.239319
# reglamento-editorial-de-la-universidad-de-gauan...                                           0.236354
# reglamento-de-mecanismos-alternos-de-solucion-d...                                           0.238923
# reglameto-de-responsabilidades-en-el-entorno-un...                                           0.234626
#
#                                                     Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think rouge2  \
# ley-organica-de-la-universidad-de-guanajuato                                                 0.138469
# reglamento-del-personal-academico-de-la-univers...                                           0.218602
# reglamento-de-distinciones-universitarias-de-la...                                           0.241885
# reglamento-de-la-junta-directiva-de-la-universi...                                           0.238330
# reglamento-para-la-incorporacion-al-regimen-aca...                                           0.218214
# reglamento-interno-del-patronato-de-la-universi...                                           0.210942
# reglamento-de-quienes-integran-la-orquesta-sinf...                                           0.209046
# reglamento-academico-de-la-universidad-de-guana...                                           0.205576
# codigo-de-etica-de-las-personas-servidoras-publ...                                           0.202285
# reglamento-de-la-defensoria-de_los-derechos-hum...                                           0.205322
# reglamento-de-responsabilidades-y-sanciones-en-...                                           0.195220
# estatuto-organico-de-la-universidad-de-guanajuato                                            0.189812
# reglamento-de-transparencia-y-acceso-a-la-infor...                                           0.184158
# reglamento-de-bienes-del-patrimonio-cultural-de...                                           0.187263
# codigo-de-etica-universidad-de-guanajuato                                                    0.184520
# reglamento-del-programa-de-estimulos-al-dsempen...                                           0.184567
# codigo_conducta_e_integridad_personas_servidora...                                           0.182606
# reglamento-de-becas-apoyos-y-estimulos-estudian...                                           0.182713
# reglamento-editorial-de-la-universidad-de-gauan...                                           0.180358
# reglamento-de-mecanismos-alternos-de-solucion-d...                                           0.181850
# reglameto-de-responsabilidades-en-el-entorno-un...                                           0.178233
#
#                                                     Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think rougeL  \
# ley-organica-de-la-universidad-de-guanajuato                                                 0.171591
# reglamento-del-personal-academico-de-la-univers...                                           0.256543
# reglamento-de-distinciones-universitarias-de-la...                                           0.281501
# reglamento-de-la-junta-directiva-de-la-universi...                                           0.277515
# reglamento-para-la-incorporacion-al-regimen-aca...                                           0.256964
# reglamento-interno-del-patronato-de-la-universi...                                           0.249080
# reglamento-de-quienes-integran-la-orquesta-sinf...                                           0.247863
# reglamento-academico-de-la-universidad-de-guana...                                           0.242373
# codigo-de-etica-de-las-personas-servidoras-publ...                                           0.238509
# reglamento-de-la-defensoria-de_los-derechos-hum...                                           0.243184
# reglamento-de-responsabilidades-y-sanciones-en-...                                           0.233451
# estatuto-organico-de-la-universidad-de-guanajuato                                            0.226885
# reglamento-de-transparencia-y-acceso-a-la-infor...                                           0.221087
# reglamento-de-bienes-del-patrimonio-cultural-de...                                           0.224489
# codigo-de-etica-universidad-de-guanajuato                                                    0.222109
# reglamento-del-programa-de-estimulos-al-dsempen...                                           0.221704
# codigo_conducta_e_integridad_personas_servidora...                                           0.219718
# reglamento-de-becas-apoyos-y-estimulos-estudian...                                           0.219761
# reglamento-editorial-de-la-universidad-de-gauan...                                           0.217173
# reglamento-de-mecanismos-alternos-de-solucion-d...                                           0.219504
# reglameto-de-responsabilidades-en-el-entorno-un...                                           0.216134
#
#                                                     Qwen/Qwen3-Embedding-8B_Qwen3-8B-Q4_K_M-think rougeLsum
# ley-organica-de-la-universidad-de-guanajuato                                                 0.175655
# reglamento-del-personal-academico-de-la-univers...                                           0.266521
# reglamento-de-distinciones-universitarias-de-la...                                           0.291481
# reglamento-de-la-junta-directiva-de-la-universi...                                           0.287827
# reglamento-para-la-incorporacion-al-regimen-aca...                                           0.264687
# reglamento-interno-del-patronato-de-la-universi...                                           0.256047
# reglamento-de-quienes-integran-la-orquesta-sinf...                                           0.254758
# reglamento-academico-de-la-universidad-de-guana...                                           0.249085
# codigo-de-etica-de-las-personas-servidoras-publ...                                           0.244969
# reglamento-de-la-defensoria-de_los-derechos-hum...                                           0.249577
# reglamento-de-responsabilidades-y-sanciones-en-...                                           0.239886
# estatuto-organico-de-la-universidad-de-guanajuato                                            0.233651
# reglamento-de-transparencia-y-acceso-a-la-infor...                                           0.227817
# reglamento-de-bienes-del-patrimonio-cultural-de...                                           0.231285
# codigo-de-etica-universidad-de-guanajuato                                                    0.228701
# reglamento-del-programa-de-estimulos-al-dsempen...                                           0.228655
# codigo_conducta_e_integridad_personas_servidora...                                           0.226661
# reglamento-de-becas-apoyos-y-estimulos-estudian...                                           0.226382
# reglamento-editorial-de-la-universidad-de-gauan...                                           0.223617
# reglamento-de-mecanismos-alternos-de-solucion-d...                                           0.225680
# reglameto-de-responsabilidades-en-el-entorno-un...                                           0.221767
